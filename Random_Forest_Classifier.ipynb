# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My Drive/Task #Change Directory according to your system
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/Task #Change Directory according to your system'
# /content/gdrive/My Drive/Task

# %% [markdown]
# Import necessary libraries and dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Load data from csv file
dataset = pd.read_csv('ModelData.csv')
dataset = pd.DataFrame(dataset)
dataset.head(10)
# Out:
#       RMS      CC        F0        F1  Class
# 0  2.1159  0.9834  3.116531  0.176920      0
# 1  1.8772  0.9733  2.212684  2.392617      0
# 2  1.9290  0.9822  2.338491  2.575447      0
# 3  1.8216  0.9777  2.555161  2.578739      0
# 4  1.6639  0.9715  2.010262  2.036390      0
# 5  0.1677  0.4323  0.218718  0.013475      1
# 6  3.0635  0.9528  3.492780  3.773862      1
# 7  2.0692  0.9781  2.835503  2.953903      1
# 8  2.1089  0.9816  2.378931  2.661001      1
# 9  1.8292  0.9464  2.233631  2.253951      1

# %%
dataset.shape
# Out:
# (55, 5)

# %% [markdown]
# Data Augmentation

# %%
dataset = dataset.append(dataset, ignore_index = True)
dataset = dataset.append(dataset, ignore_index = True)
dataset = dataset.append(dataset, ignore_index = True)

# %%
dataset.shape
# Out:
# (440, 5)

# %% [markdown]
# Random Shuffling of Data

# %%
from sklearn.utils import shuffle

shuffled = shuffle(dataset)
shuffled.head(10)
# Out:
#         RMS      CC        F0        F1  Class
# 189  2.6608  0.9569  3.442073  3.494684      4
# 397  2.8177  0.9919  3.612397  3.665143      2
# 408  0.1659  0.3805  0.080636  0.186513      4
# 160  3.0302  0.9787  4.132689  4.170590     10
# 45   2.3757  0.9855  3.140776  3.170726      9
# 32   2.0692  0.9794  2.446998  2.645486      6
# 9    1.8292  0.9464  2.233631  2.253951      1
# 294  2.6608  0.9569  3.442073  3.494684      3
# 137  2.1873  0.9828  2.929886  3.060754      5
# 127  0.1672  0.4122  0.096062  0.264574      3

# %%
shuffled.shape
# Out:
# (440, 5)

# %% [markdown]
# Data Splitting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(shuffled.iloc[:,:4], shuffled.Class ,test_size = 0.20, random_state = 42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (352, 4)
# (352,)
# (88, 4)
# (88,)

# %% [markdown]
# Model Fitting - Random Forest

# %%
# Train the Random Forest model
model = RandomForestClassifier(n_estimators = 100 ,random_state= 42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model.score(X_test,y_test)
# Out:
# 0.9431818181818182

# %%
# Make predictions on the test set
y_pred =model.predict(X_test)

# %% [markdown]
# Model Accuracy

# %%
# Evaluate the performance of the model using accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 score: ", f1)
# Out:
# Accuracy:  0.9431818181818182
# Precision:  0.965034965034965
# Recall:  0.9431818181818182
# F1 score:  0.9424698108908636

# %% [markdown]
# Confusion Matrix

# %%
# !matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel = ('Predicted')
plt.ylabel = ('Truth')
# Out:
# /bin/bash: matplotlib: command not found
